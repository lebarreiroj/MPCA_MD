# %%
import tabula
import pandas as pd

# %%
column_names = [ 'Km Inicio',
                 'Km Fim',
                 'UF',
                 'Largura da Faixa 1',
                 'Largura da Faixa 2',
                 'Largura da Faixa 3',
                 'Largura do Acostamento',
                 'Tipo de Pista']

# %%
# Create empty DataFrame with those column names
tipo_pista = pd.DataFrame(columns=column_names)

# %%
#tp_pista_pag3

# %%
lista_tabelas = tabula.read_pdf("tipo_pista_via040.pdf", pages="1")

# %%
len(lista_tabelas)
# Out:
# 1

# %%
lista_tabelas = tabula.read_pdf("tipo_pista_via040.pdf", pages="1")
for tabela in lista_tabelas:
    #tabela = df.rename(columns={'nome': 'nome_completo'})
    dftmp = tabela.copy()
    
    dftmp.rename({'Km InícioKm Fim': 'Km Inicio', 
                  'Estado': 'Km Fim', 
                  'Largura da Faixa 1\rNorte (m)': 'UF', 
                  'Largura da Faixa 2\rNorte(m)': 'Largura da Faixa 1', 
                  'Largura da Faixa 3\rNorte(m)': 'Largura da Faixa 2',
                  'Largura do\rAcostamento (m)':'Largura da Faixa 3',
                  'Tipo de pista':'Largura do Acostamento',
                  'Unnamed: 0':'Tipo de Pista'}, axis = 1, inplace = True)

    display(dftmp)
    tipo_pista_page1 = dftmp.copy()
# Out:
#    Km Inicio Km Fim  UF Largura da Faixa 1 Largura da Faixa 2  \
# 0      0,000    0,8  DF                3,5                3,3
# 1      0,800    2,8  DF               3,45                3,3
# 2      2,800    3,3  DF                3,5                3,3
# 3      3,300    4,5  DF                3,5                3,3
# 4      4,500    5,6  DF               3,45                3,3
# ..       ...    ...  ..                ...                ...
# 67   231,000    238  MG                3,4                NaN
# 68   238,000  241,6  MG                3,4                NaN
# 69   241,600    248  MG               3,45                NaN
# 70   248,000  252,4  MG               3,35                3,3
# 71   252,400  253,4  MG               3,45                NaN
#
#     Largura da Faixa 3 Largura do Acostamento Tipo de Pista
# 0                  NaN                    1,5         Dupla
# 1                  NaN                    1,5         Dupla
# ...

# %%
lista_tabelas = tabula.read_pdf("tipo_pista_via040.pdf", pages="3")
for tabela in lista_tabelas:
    #tabela = df.rename(columns={'nome': 'nome_completo'})
    dftmp = tabela.copy()
    
    dftmp.rename({'km Iníciokm Fim': 'Km Inicio', 
                  'Estado': 'Km Fim', 
                  'Largura da Faixa 1\rNorte (m)': 'UF', 
                  'Largura da Faixa 2\rNorte(m)': 'Largura da Faixa 1', 
                  'Largura da Faixa 3\rNorte(m)': 'Largura da Faixa 2',
                  'Largura do\rAcostamento (m)':'Largura da Faixa 3',
                  'Tipo de pista':'Largura do Acostamento',
                  'Unnamed: 0':'Tipo de Pista'}, axis = 1, inplace = True)

    display(dftmp)
    tipo_pista_page3 = dftmp.copy()
# Out:
#    Km Inicio Km Fim  UF Largura da Faixa 1 Largura da Faixa 2  \
# 0          0   0,24  DF                3,6                3,6
# 1       0,24    2,8  DF               3,45               3,45
# 2        2,8    3,3  DF               3,45               3,45
# 3        3,3    8,2  DF                3,5                3,4
# 4          0     25  GO                3,6               3,45
# ..       ...    ...  ..                ...                ...
# 67     241,6    248  MG               3,45                NaN
# 68       248  252,4  MG               3,45                NaN
# 69     252,4  253,4  MG               3,45                NaN
# 70     253,4  254,6  MG                3,5                NaN
# 71     254,6  259,8  MG                3,5                NaN
#
#     Largura da Faixa 3 Largura do Acostamento Tipo de Pista
# 0                  NaN                    2,5         Dupla
# 1                  NaN                    2,5         Dupla
# ...

# %%
lista_tabelas = tabula.read_pdf("tipo_pista_via040.pdf", pages="2")
for tabela in lista_tabelas:
    #tabela = df.rename(columns={'nome': 'nome_completo'})
    dftmp = tabela.copy()
    
    dftmp.rename({'253,400': 'Km Inicio', 
                  '254,6': 'Km Fim', 
                  'MG': 'UF', 
                  '3,4': 'Largura da Faixa 1', 
                  '3,4.1': 'Largura da Faixa 2',
                  'Unnamed: 0':'Largura da Faixa 3',
                  'Unnamed: 1':'Largura do Acostamento',
                  'Simples':'Tipo de Pista'}, axis = 1, inplace = True)
    
    '''
    253,400
    254,6
    MG
    3,4
    3,4.1
    Tipo de Pista
    Unnamed: 1
    Simples
    '''
    display(dftmp)
    tipo_pista_page2 = dftmp.copy()
# Out:
#    Km Inicio Km Fim  UF Largura da Faixa 1 Largura da Faixa 2  \
# 0    254,600  259,8  MG                3,5                NaN
# 1    259,800  262,4  MG               3,45                3,4
# 2    262,400  276,4  MG                3,5                NaN
# 3    276,400    280  MG               3,55                NaN
# 4    280,000    282  MG                3,5                NaN
# 5    282,000    283  MG               3,55                NaN
# 6    283,000    290  MG               3,45                NaN
# 7    290,000  291,4  MG               3,55                NaN
# 8    291,400    293  MG               3,45                3,4
# 9    293,000  293,6  MG               3,45                NaN
# 10   293,600  294,2  MG                3,4                3,4
# 11   294,200    295  MG                3,4                NaN
# 12   295,000  295,8  MG               3,45                3,4
# 13   295,800  296,4  MG                3,5                NaN
# ...

# %%
lista_tabelas = tabula.read_pdf("tipo_pista_via040.pdf", pages="4")
for tabela in lista_tabelas:
    #tabela = df.rename(columns={'nome': 'nome_completo'})
    dftmp = tabela.copy()
    
    dftmp.rename({'253,400': 'Km Inicio', 
                  '254,6': 'Km Fim', 
                  'MG': 'UF', 
                  '3,4': 'Largura da Faixa 1', 
                  '3,4.1': 'Largura da Faixa 2',
                  'Unnamed: 0':'Largura da Faixa 3',
                  'Unnamed: 1':'Largura do Acostamento',
                  'Simples':'Tipo de Pista'}, axis = 1, inplace = True)
    
    '''
    253,400
    254,6
    MG
    3,4
    3,4.1
    Tipo de Pista
    Unnamed: 1
    Simples
    '''
    display(dftmp)
    tipo_pista_page2 = dftmp.copy()
# Out:
#     259,8  262,4  UF  3,55 Largura da Faixa 3 Largura do Acostamento  2,65  \
# 0   262,4  276,4  MG   3,5                NaN                    NaN  2,55
# 1   276,4    280  MG  3,45                3,4                    NaN   NaN
# 2     280    282  MG   3,5                NaN                    NaN  2,55
# 3     282    283  MG  3,45                3,4                    NaN   NaN
# 4     283    290  MG  3,45                NaN                    NaN  2,55
# 5     290  291,4  MG  3,45                3,4                    NaN   NaN
# 6   291,4    293  MG   3,5                NaN                    NaN  2,55
# 7     293  293,6  MG  3,45                NaN                    NaN   2,5
# 8   293,6  294,2  MG   3,5                NaN                    NaN  2,55
# 9   294,2    295  MG   3,4                NaN                    NaN   2,5
# 10    295  295,8  MG   3,5                NaN                    NaN   2,7
# ...

# %%
for tabela in lista_tabelas:
    #tabela = df.rename(columns={'nome': 'nome_completo'})
    tipo_pista = tabela.rename({'Km InícioKm Fim': 'Km Inicio', 
                                'Estado': 'Km Fim', 
                                'Largura da Faixa 1\rNorte (m)': 'UF', 
                                'Largura da Faixa 2\rNorte(m)': 'Largura da Faixa 1', 
                                'Largura da Faixa 3\rNorte(m)': 'Largura da Faixa 2',
                                'Largura do\rAcostamento (m)':'Largura da Faixa 3',
                                'Tipo de pista':'Largura do Acostamento',
                                'Unnamed: 0':'Tipo de Pista'}, axis = 1)
    display(tipo_pista)
# Out:
#    Km Inicio Km Fim  UF Largura da Faixa 1 Largura da Faixa 2  \
# 0      0,000    0,8  DF                3,5                3,3
# 1      0,800    2,8  DF               3,45                3,3
# 2      2,800    3,3  DF                3,5                3,3
# 3      3,300    4,5  DF                3,5                3,3
# 4      4,500    5,6  DF               3,45                3,3
# ..       ...    ...  ..                ...                ...
# 67   231,000    238  MG                3,4                NaN
# 68   238,000  241,6  MG                3,4                NaN
# 69   241,600    248  MG               3,45                NaN
# 70   248,000  252,4  MG               3,35                3,3
# 71   252,400  253,4  MG               3,45                NaN
#
#     Largura da Faixa 3 Largura do Acostamento Tipo de Pista
# 0                  NaN                    1,5         Dupla
# 1                  NaN                    1,5         Dupla
# ...

# %%
# Extract column names into a list
column_names = [x for x in tipo_pista.columns]

# %%
column_names
# Out:
# ['Km Inicio',
#  'Km Fim',
#  'UF',
#  'Largura da Faixa 1',
#  'Largura da Faixa 2',
#  'Largura da Faixa 3',
#  'Largura do Acostamento',
#  'Tipo de Pista']

# %%
import xgboost
import shap

# train an XGBoost model
X, y = shap.datasets.boston()
model = xgboost.XGBRegressor().fit(X, y)

# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[0])
# Out:
# Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
# ...

# %%
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...
